# %% [markdown]
# # InstaBot Introduction - Part 1
#
# Your friend has opened a new Food Blogging handle on Instagram and wants to get famous. He wants to follow a lot of people so that he can get noticed quickly but it is a tedious task so he asks you to help him. As you have just learned automation using Selenium, you decided to help him by creating an Instagram Bot.
# You need to create different functions for each task.
# Note :
# Don’t forget to remove your Username and Password from the python notebook before submission.
# Replace your username and password by ‘SAMPLE USERNAME’ and ‘SAMPLE PASSWORD’ where you have used them in your code for logging in to instagram
# Upload your code file for submission of this project

# %% [markdown]
# # InstaBot - Part 1
# 1. Login to your Instagram Handle
#    1. Submit with sample username and password
#
# 2. Type for “food” in search bar and print all the names of the Instagram Handles that are displayed in list after typing “food”
#    1. Note : Make sure to avoid printing hashtags
#
# 3. Searching and Opening a profile using
#    1. Open profile of “So Delhi”
#
# 4. Follow/Unfollow given handle -
#     Open the Instagram Handle of “So Delhi”
#    A. Start following it. Print a message if you are already following
#    B. After following, unfollow the instagram handle. Print a message if you have already unfollowed.
#
# 5. Like/Unlike posts
#    1. Liking the top 30 posts of the ‘dilsefoodie'. Print message if you have already liked it.
#    2. Unliking the top 30 posts of the ‘dilsefoodie’. Print message if you have already unliked it.
#
# 6. Extract list of followers
#    1. Extract the usernames of the first 500 followers of ‘foodtalkindia’ and ‘sodelhi’.
#    2. Now print all the followers of “foodtalkindia” that you are following but those who don’t follow you.
#
# 7. Check the story of ‘coding.ninjas’.

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Prerequisite For Running this Kernal----- Better Strength of Internet Connection

# %% [markdown]
# 1. Login to your Instagram Handle
#    1. Submit with sample username and password

# %% [markdown]
# #### Please Enter the Username in place of 'SAMPLE USERNAME' and Password in place of 'SAMPLE PASSWORD' for running this kernal

# %%
#importing library and class for webdriver and for explicte waiting
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait#for using explicite waiting
from selenium.webdriver.support import expected_conditions as EC# for locating certain element
from selenium.webdriver.common.by import By# for by which condition we want to locate
import time

# %%
# executing a new chrome driver to open Instagram
driver=webdriver.Chrome(executable_path="/Users/karna/Desktop/chromedriver")
driver.maximize_window()
#driver opening website of Instagram
driver.get("https://www.instagram.com/")
# it is for explicite waiting for 10 sec, when ever waiting required We will use it 
wait=WebDriverWait(driver,10)
#locating the area where we can enter username
email1=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"_2hvTZ")))
#entering the usename
email1.send_keys("arjunsuritamaa")
#locating the area and sending the password
driver.find_element_by_name("password").send_keys("E15pb2110863")
#now submiting the username and password
driver.find_element_by_class_name("sqdOP").submit()
#locating the popup-window
clickable=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"cmbtv")))
clickable.click()
#locating againg the popup_window
clickable=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"HoLwm")))
clickable.click()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-8-efa1354c4c57> in <module>
#       3 driver.maximize_window()
#       4 #driver opening website of Instagram
# ----> 5 driver.get("https://www.instagram.com/")
#       6 # it is for explicite waiting for 10 sec, when ever waiting required We will use it
#       7 wait=WebDriverWait(driver,10)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: net::ERR_INTERNET_DISCONNECTED
#   (Session info: chrome=101.0.4951.41)

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# 2. Type for “food” in search bar and print all the names of the Instagram Handles that are displayed in list after typing “food”
#    1. Note : Make sure to avoid printing hashtags

# %%
driver.get("https://www.instagram.com/")
#clicking on search bar of instagram
driver.find_element_by_class_name("eyXLr").click()
#typing "food" in search bar
driver.find_element_by_class_name("XTCLo").send_keys("food")
 
#locating all username who appered after typing 'food'
time.sleep(3)
food_list=driver.find_elements_by_class_name("fuqBx")
final_list=[]
for i in food_list:
    listing=i.text.split('\n')

    k=0
    
    

    for p in listing:
        if(k%2!=0):
            k=k+1
            continue
        if('#' in p):
            p=p[1:]
        
        final_list.append(p)
        k=k+1
print(final_list)
driver.get("https://www.instagram.com/")
# Out:
# ['foodieee.desifoods', 'food_for_love___', 'foodie_incarnate', 'dilsefoodie', 'food_food_surat', 'khao_piyo_food_vlogs', 'food', 'food_lunatic', 'foodies_findings', 'foodiesafarii', 'yourfoodlab', 'foodaholic_us', 'warangal.food.diaries', 'foodtravelbike', '_foodie_dilse_', 'the.food_cult', 'thisisdelhi', 'foodmapjaipur', 'kalsedietchalu', 'food.ternion', 'food.ieboss', 'foodfood3637', 'food', 'food4life94', 'zaika_patna_ka', 'desi_food_panda', 'delhifoodwalks', 'food_blogger290', 'foodchoiceofmumbai', 'food_era_', 'food_columnist_', 'food_quotient', 'twin_food_delight', 'foodie_rucchi', 'foodfoodtv', 'delhifoodnest', 'dying_for_food', 'streetfoodrecipe', 'hungers_ki_kitchen', 'foodporn', 'foodie', 'Food Foundry', 'the_ultimate_food_stalkers', 'foodiegram_nagpur', 'foodiehot_bazaar', '_food.icious_', 'food_gasmic_famous', 'nashiktales', 'foodieslovetowander', 'foodblogger', '_foodie_babu', 'girly_n_gluttony', 'satisflying_food', 'foodie_licious_hungerr', 'foodophile_23', 'chili_herb']

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# 3. Searching and Opening a profile using
#    1. Open profile of “So Delhi”

# %%
driver.get("https://www.instagram.com/")
#locating searchbar
driver.find_element_by_class_name("eyXLr").click()

driver.find_element_by_class_name("XTCLo").send_keys("So Delhi")
SoDelhi=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"-qQT3")))
SoDelhi.click()

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# 4. Follow/Unfollow given handle -
#    A. Start following it. Print a message if you are already following

# %%
driver.get("https://www.instagram.com/")
#locating searchbar
driver.find_element_by_class_name("eyXLr").click()

driver.find_element_by_class_name("XTCLo").send_keys("So Delhi")
SoDelhi=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"-qQT3")))
SoDelhi.click()
time.sleep(5)
try:
    #locating follow button
    follow=driver.find_element_by_class_name("jIbKX")
    follow.click()
    print("Now you are Follwing")
except:
    print("You are already Following")
driver.get("https://www.instagram.com/")
# Out:
# You are already Following

# %% [markdown]
# 4. Follow/Unfollow given handle -
#    B. After following, unfollow the instagram handle. Print a message if you have already unfollowed.

# %%
driver.get("https://www.instagram.com/")
#locating searchbar
driver.find_element_by_class_name("eyXLr").click()

driver.find_element_by_class_name("XTCLo").send_keys("So Delhi")
SoDelhi=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"-qQT3")))
SoDelhi.click()
time.sleep(5)
try:
    #locating follow button
    driver.find_element_by_class_name("-fzfL").click()
    unfollow=driver.find_element_by_class_name("aOOlW")
    unfollow.click()
    print("Now you are UnFollowing")
except:
    print("You are already UnFollowing")
driver.get("https://www.instagram.com/")
# Out:
# Now you are UnFollowing

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# 5. Like/Unlike posts
#    5.1 Liking the top 30 posts of the ‘dilsefoodie'. Print message if you have already liked it.

# %%
driver.get("https://www.instagram.com")
driver.find_element_by_class_name("eyXLr").click()
driver.find_element_by_class_name("XTCLo").send_keys("dilsefoodie")

dilsefoodie=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"-qQT3")))
dilsefoodie.click()
time.sleep(3)
post=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"eLAPa")))
post.click()


heart=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"fr66n")))
fill=str(heart.get_attribute("outerHTML"))
if(not "#ed4956" in fill):
    heart.click()

for i in range(29):
    driver.find_element_by_class_name("l8mY4").click()
    heart=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"fr66n")))
    fill=str(heart.get_attribute("outerHTML"))
    if("#ed4956" in fill):
        pass
    else:
        heart.click()
    time.sleep(3)
print("You have Liked first 30 posts of dilsefoodie")
driver.get("https://www.instagram.com/")
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-6-8ebf460338fd> in <module>
#       3 driver.find_element_by_class_name("XTCLo").send_keys("dilsefoodie")
#       4
# ----> 5 dilsefoodie=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"-qQT3")))
#       6 dilsefoodie.click()
#       7 time.sleep(3)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\support\wait.py in until(self, method, message)
#      78             if time.time() > end_time:
#      79                 break
# ---> 80         raise TimeoutException(message, screen, stacktrace)
#      81
#      82     def until_not(self, method, message=''):
#
# TimeoutException: Message:

# %% [markdown]
# 5. Like/Unlike posts
#    5.2 Unliking the top 30 posts of the ‘dilsefoodie’. Print message if you have already unliked it.

# %%
import time
driver.get("https://www.instagram.com/")
driver.find_element_by_class_name("eyXLr").click()
driver.find_element_by_class_name("XTCLo").send_keys("dilsefoodie")
dilsefoodie=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"-qQT3")))
dilsefoodie.click()
time.sleep(3)
post=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"eLAPa")))
post.click()
heart=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"fr66n")))
fill=str(heart.get_attribute("outerHTML"))
if("#ed4956" in fill):
    heart.click()


for i in range(29):
    driver.find_element_by_class_name("l8mY4").click()
    heart=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"fr66n")))
    fill=str(heart.get_attribute("outerHTML"))
    if("#ed4956" in fill):
        heart.click()
print("You have disliked first 30 posts of dilsefoodie")
driver.get("https://www.instagram.com/")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-5-221325c6f352> in <module>
#       1 import time
# ----> 2 driver.get("https://www.instagram.com/")
#       3 driver.find_element_by_class_name("eyXLr").click()
#       4 driver.find_element_by_class_name("XTCLo").send_keys("dilsefoodie")
#       5 from bs4 import BeautifulSoup
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=100.0.4896.127)

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# 6. Extract list of followers
#    1. Extract the usernames of the first 500 followers of ‘foodtalkindia’ and ‘sodelhi’.

# %%
 #6.1 Extracting the username of the first 500 followers of "foodtalkindia"

driver.get("https://www.instagram.com/")
driver.find_element_by_class_name("eyXLr").click()# finding search bar
driver.find_element_by_class_name("XTCLo").send_keys("foodtalkindia")# searching foodtalkindia in searchbar

foodtalkindia=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"-qQT3")))
foodtalkindia.click()# clikcing on searched name appeared as foodtalkindia

follower=wait.until(EC.presence_of_element_located((By.XPATH,"//ul[@class='k9GMp ']//a")))
follower.click()# cliking on follower button

scr1=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"isgrP")))# now locating the pop window appeared in which followers name occured

driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)# scrolling the popup page
username_foodtalkindia=driver.find_elements_by_class_name("notranslate")# creating the list of object of all username appearing on followers pop-up window
print(username_foodtalkindia)

while(len(username_foodtalkindia)<=500):# same process goes on till finding the 500 object of username in followers popup page
    username_foodtalkindia=driver.find_elements_by_class_name("notranslate")
    
    driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)
    
print("Followers of foddtalkindia : ")
print()

for i in range(500):
    username_foodtalkindia[i]=str(username_foodtalkindia[i].get_attribute("title"))# now extracting the username from username selenium object
    print(username_foodtalkindia[i])
    
driver.get("https://instagram.com/")
# Out:
# []
# Followers of foddtalkindia :
#
# wewhineanddine
# yuphorian
# 1313_krish
# 96vanessa_ferrara
# samyukthaahuman
# abhishek_ranaa
# uday31813
# adaayakhan123
# rahatarora
# nik0335
# yomamascookin
# __ritik_bhagat__
# 24framz
# hotelroyal77
# nirvana_jajabara
# shaan_e_dilli1986
# royal_kunwar_036
# vaishalisonwane2018
# harneetkaurarora
# vmlsenthilpriya
# sukriti_tyagi_mua
# shallu_bhatia
# bstunning_official
# mahira_lovely
# sais_hakhanna
# investor_brain_nestor_frxtrade
# shwetagaind
# vaishali.1186
# nishthalalwani
# shtl_k
# foodonwheels90
# dhaanukaa
# dgiantsky
# gauravmendiratta
# khushismile14
# wanderlust9082
# wwwrajkumar061
# anitachitti
# bharat_bughani
# nadil_nazz
# malisiddhesh726
# anujeetm
# notorious_alpha
# my.love.dilip.rj09
# kaajalthakurrr
# priyasha_baid
# kunal.jatania
# status_lover_0_0_0_1
# its_par_na
# trio_homestay
# _.omprakashmishra._
# imgharey
# shailesh_shailud
# riya_chef_
# __food.monkey
# satoru.namikaze
# rakshann_shetty
# aishwaryasati
# jerin_abbus
# rikitaparikh
# suruchihomelyfoods
# akshaykawde750
# akshay_khatri_47
# haralepriyankaashok4
# munishworld
# mohitha_krishna
# sasikala.baskaran
# epicurean_gram
# stepwithca
# thecheesygourmet
# aamirkhan.law
# princess_97038210
# raji_trl
# ruhimchauhan
# sanavsfood
# ris_hi7033
# ___anant___03
# 0786_hayaat
# radhhika.bmehraa
# ekaurphotographer_
# waqaralam2022
# mehulsavla
# jjaisehgal
# venkata_krishna_sai
# poojawonderangel93
# sheenam_pankaj_bajaj
# madhurisfoodmagic
# hungry_young_mann
# abeerakhanna
# sunilmalav
# akshay.bhasin1
# lottathingsthosay
# raj_yarlagadda
# reemabagde
# radsmurarka
# sahil_xe05
# riddhijasani
# mahika.heda
# neverenoughpasta
# kurrebhisma
# chefbusraa6
# chef_neupane
# sukhumode
# ayesha1232290
# ihbarus
# darshanparmar17
# chefpawan.bill
# dr_shiva_saigal
# chandrashreeeee
# thefoodieleo
# bloom.foodie
# anj_hari
# monkparas
# esarin_04
# unique_rubi6
# ____.regards_shraddha.____
# ritulahoti
# delhiindia98
# zara.yete
# 75swati
# shubham99
# mariaahmed716
# indamahendrasingh992_07
# shor_mishtii
# kavyathakur_0410
# tasting_india
# deekshaksonalkar
# prince.318
# 0mor.ality
# ojasvi2901
# harshitasharma021
# ashboom21
# lahotivandana
# lips_duet
# madhavbhushan
# devansh_taneja
# lavishjaiswal
# ji.bhaiyaji
# shalini.guptan
# gurgaon.eats
# indhu.630
# chaitra.24
# hunger.plate
# mohd_ameen_delightpack
# abhishekkudale
# ajinkyaambekar89gmail.com8
# shivanisingh9703
# stylesoul71
# travelandglam786
# townsendjaipur
# cookdilse_neel
# zsl3511
# madhukaurrakeshkumar
# anshikajjjj_
# ranii_kaur
# kajal_11_05
# blosring
# chef.temi2022
# akashcosmic
# veg._foodie
# kchatwal
# atitude_queen_40
# arf_rancis
# bhairavi_t
# aishwarya.a.ashok
# flaneur_30
# indianfeastrecipe
# _swaddy16_
# moh5577amed
# kalalisaikirangoud007
# stalwart73
# albatrosses_24
# offthewallforever
# satiz_insta
# shreyashah22
# rebeccavv
# ankuchidu
# vi_srikanth
# sakshi_modi1119
# vkasgrace
# its_saif_phatan
# jinalnishar
# matu_mir_
# kolkatacafes
# perfects_nourriture
# aasthabanthia
# cellvish1212
# dan_sakari_martyn
# ama_kunji_ovucha_muta
# urban__savage__
# jaigaddam
# savvys_food_stories
# sachin_blr123
# archana.parikh
# s_anch_r
# idemonjoe
# juhishah93
# raashiagr
# herecomesjony
# meruba04
# jagstagram_03
# samarthmehrotra16
# parthamberkar
# ahujajyotika
# mdan._.shoaib
# dailystreetfood1
# _visshalll_
# eshwardhortre
# shwetabaag
# mahaveer_979
# goldenfalcon666
# jinaljain566
# surya_prakash1230
# pinki_saha_5050
# vesheshta06
# mistu_varsa
# desitouchcooking
# rituraj2881
# rushil_khedekar
# ishakhushal
# supe_rstarssajidabbasi01
# arbindmogiya
# girishadogra
# trip.hungry
# mohitrajpoot23
# _creativepalate_
# preetivarshney8
# hemantgandhi1234.hg
# chirag3089
# hailey_hy1993
# satyaprakashpiku
# manish.gro99
# udipta_karmakar
# willfredwolf
# vishal_kr.gupta
# _cat_valentine_xx
# impulsive_indeed
# nawal_aljaabri
# atomicnumber73
# salaar_saha_00
# antonym1_
# destination_fitworld
# les.lieux.fuyants
# khushnaazkaikobad
# mohit_voyage
# mukesh.sah113
# seeker_687
# itstickel.star
# rahoullasod23
# abhisek_jain46
# msc.cs.rockers2017
# delilahscafedelhi
# rupeshkadhao
# vignesh_donkey_2814_
# i_am_pushpendu
# quirxee
# drfnbcompany
# bobma1991wc4snhmx
# chiragmehta593
# kspmuthukumar
# samipjadhav31
# dakshita_kumari767
# hamza6800khan
# swatijain.1
# chait_94
# imavirgogirl
# nabs9202
# chopranipun
# sakshammakhija
# skillzsrikanth
# ghoshpriyanka6930
# me_anku
# chauhan_av
# mriduthakur.pvt
# rohitv46
# shefaliipatil
# hungry3803
# hermit.coffee
# poorvisaluja
# aman_choudhary7
# shrutiii_kt
# nishant.kumar.thakur
# jayant.jitu
# kalpita_deshmukh
# dwix_dwyx_6789
# abhang_dhiraj
# its_charan_5k
# meherkvaswani
# bushrakhan54272
# tasneemjah
# olisagar1982
# deepamalhotra2205
# hameersinghjhala
# nitesh.gupta.1985
# sip.of.sky
# bitesof_food
# nafihsahkeel999
# goala_jeet
# nihitha_alicherry
# thomasnickm
# monaa_tripathi
# gurtejsingh384
# digitalpratik_
# nidhitodi24
# seema_budholia
# sumitrabehera_1997
# cremennuts_icecream
# jayu_thakor_1_13_7
# tempting_treats77
# iamyahiya_official
# priyakhurana15
# abinayaa_1234
# kalam_ki_gunjaayish
# tarunsharma88
# shahrukhkhanpathan85
# to_her_focus_8
# pavan_gagare
# sk_mezbah_uddin_13579
# aneeshpampadi
# alkasinghthakur
# cuteangel3619
# hansikaratan
# kczala_1333
# neha__97
# jay__engineering
# pooja_mitter
# anmolneelcooks
# rave.infinity
# chef_sundar_kant
# ujwala_s92
# one_who_explores
# jyotsnamalhotra31
# rywartch
# golden_boys_90
# ibrahim.vajih
# krishnabakery2021
# _nehashukla
# aqsazahid410
# shahdhussien241
# foodworld__7
# julmar_tec
# ri_saku
# cr_0004
# kapil.makhija04
# nutandev01
# lakshmanmohan
# sudakshinadaas
# raje.shree17
# shreyadutt_
# san._.d
# subhothep
# bakewithdhruvi
# yug0089
# karishma11.11
# shutsuka_
# whiteshirt_san
# ephiphany.555
# chintaguntaarun
# daravnaduck
# vipulbhatia21
# theyhaveakey
# its_preetygaur
# shaikirfan12399
# shiva.agrawal
# abhi_khayenge
# mehakvv202gmail.com6
# kc_nars
# rohit.s392
# saqlanes2181
# jeet.magar84
# nayak.rohit7
# _armaan_khan_786_8434
# rigzinsimba
# lucas_sumanam
# dolkhar.ladakh
# rigzinlachic
# zuhain_sk
# nmpnga
# kunwardurga2021
# varunsaigal04
# rajesh.gogate
# d0nda_cam
# mpsmegh
# theyellowslice
# ashleythethinker
# mukundrathi
# officialomkar007
# mazinpatel
# chili_herb
# anishavarma
# sri_yadavtr36013
# afshan.k.qureshi
# chheda.nayna
# jagjitkohli
# olesh_lewis
# jatin.shah.319
# suntuzu
# ninadsaiya
# santosh_gopal
# anujjindal12
# lama_sadam
# dhireshsalian
# kashkhan_202000
# kefiening
# insane_ket
# tarzan_flips
# ameetabubber
# hashtagsupplements07
# tbhavi
# manraj_arora
# vishalbpawar
# gaurishpatil
# 3_rajukumar
# harshad.shah.85
# moon_on_earth10
# bhavint77
# dipak.gala.7
# nirav_nv7
# sandapajayanti
# ranitr007
# rituy29
# healthy.cooking17
# sachidanandsawant
# jayesh_negandhi
# mmannat4c
# ashis.h16
# sehgalnakul
# ektasoni08
# r.h.mohideen
# prathap_singh.1
# ayoojrangaraj
# impala.design
# asaanjokitchen
# motownpizzaaa
# bhorner66
# amitbhat1982
# bhowmickrohan
# darshangangar
# zk_99045
# beradebadrita3
# _ruk_h_sana_
# shriksoni
# upama_saha
# pushpak9990
# harsh_shah08
# vickzee_rj
# healthy_foodism
# add.ansari
# nisar_ahmed6
# pgriders
# mukeshpatel9919
# sukenshah_
# kirtika_jain_95
# aqib_khan.29
# krushal37
# monishi.pandya
# jigar_dharamshi
# reemasapru
# hemanthilot
# vickyaparab
# m123xy
# thetraveltracks
# sanjay_krishnan99
# nonvegpotato
# ashuu_al
# kejal_chotalia
# amitamehta50
# shreyak2601
# sudipto.ig
# rajendra.karlekar
# rohra_neeta05
# ashmita.sahni1
# narendraparmar969
# t.a.n.v.i.k
# maksusurrahman
# anshulp10
# raakesh_2805
# sirohi3900
# ashfaqahmed2447
# p4r1t05h
# navinchetwani27
# nagalakshmigangula
# food_tech_in
# advocatekaransolanki
# madhuri_padhyar
# sid_4_pawar
# kisu6027
# singhal.stuti
# sunil_mane7
# rohin_mak
# tolerant_indian
# gala.naresh
# gauresh3682
# chefoodieskitchen
# teaspoon.of.love27
# atsushiakiradavis
# vidz__04
# anku_gada
# jatinnmistryy
# kamlesh20061966

# %%
# 6.1 Extracting the username of the first 500 followers of "sodelhi"

driver.get("https://www.instagram.com/")
driver.find_element_by_class_name("eyXLr").click()# finding search bar
driver.find_element_by_class_name("XTCLo").send_keys("sodelhi")# searching sodelhi in searchbar

sodelhi=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"-qQT3")))
sodelhi.click()# clikcing on searched name appeared as sodelhi

follower=wait.until(EC.presence_of_element_located((By.XPATH,"//ul[@class='k9GMp ']//a")))
follower.click()# cliking on follower button

scr1=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"isgrP")))# now locating the pop window appeared in which followers name occured

driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)# scrolling the popup page
username_sodelhi=driver.find_elements_by_class_name("notranslate")# creating the list of object of all username appearing on followers pop-up window
while(len(username_sodelhi)<=500):# same process goes on till finding the 500 object of username in followers popup page
    username_sodelhi=driver.find_elements_by_class_name("notranslate")
    driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)
    
print("Followers of sodelhi : ")
print()

for i in range(500):
    username_sodelhi[i]=str(username_sodelhi[i].get_attribute("title"))# now extracting the username from username selenium object
    print(username_sodelhi[i])

driver.get("https://instagram.com/")
# Out:
# Followers of sodelhi :
#
# pritul_k_shah
# sabby2706
# a.none.ya
# shravani_____
# singhalsg
# aarti_siyal_
# ankit_rathore.27
# bblunt_kemps
# himanshu_kanoujiya
# kzrfaisal
# itcantfly
# swaleha.9430
# nerdkapilgupta
# maansay
# gokulnair07
# itz_anku0001
# m_9_6_7
# khaana.ba.dosh1993
# gauravsharma1079
# mzohaib221990
# abrar.dar.leh
# jindal9290
# pace_home_tutor
# priyankaa.2
# gimmemoremaggie
# anitapurig
# foodyooook
# abhishek_ranaa
# square_pantsssss
# vasundhara_raghuvanshi
# dikshaarora208
# the_plateofjoy
# oh__rio
# kavvyeaah
# avantika_1100
# vaishali_wadhawan
# my.love.dilip.rj09
# sumayla_khann
# ashii.chauhan
# lilyinmygarden
# sachin_95
# _chanchal_sharma_2003_
# veerpaljaatav
# divyaa.t_
# monika_.269
# manastiwari10
# paper_company69
# tayal_gourav
# topdentashi_
# imakashjain_48
# ritikachoudhary171
# 1incognitotrader
# jyotikabehl
# freefiremusiclover
# i_anshudangi
# _akash_goel
# seeratvirdi1
# amitydv_in
# soulb099
# _onkark0908_
# 7nidhi_pal
# aaaafxxa_
# poi.rtr
# sbasak9691
# dpk.singla1121
# jyotsananigam
# shraddhabhuwalka
# nia_sahani27
# anujashirole
# siddhantchauhan_
# jainjigeesha
# mrityunjayyyyyy
# aavleenbakshi
# rishab.narotraa
# kartik32415
# shaan_e_dilli1986
# dimple_suri_
# xemr.e80
# hrshshah96
# rashika.jawa
# ramrathore142
# shheeesssshhhhhh
# tallgirlstories111
# pikuu_23
# indiatravelogue_
# zitin.zhon
# dilrajkaur2910
# _gaurisharmaa
# aditibhotika
# jai.k.thakur___
# arnejadeepmohansingh
# selfishkidoooo
# aj_nemesis02
# _chandankumar.14_
# hemendra.singh.rajput
# priyanka.ish
# imzenithsaidi
# isoni9495
# d_patel610
# aakriticreates
# official_yadav_nee2
# sagari.c
# _astha__agrawal
# its_priyu0809
# _that_rainbowgirl
# naren7826
# makeupstories_by_gauri
# the_accidental_mariner
# khuranashikha
# ashimakhuranaofficial
# playboysievers
# reshuhora06
# pavkumar9942
# sochiqueeventsdesign
# rg_rax
# mannu_malhotra365
# _tamanna_bibyan
# nandiniii_29
# ashinawall
# bhavnavats___
# shefali_mewara
# bstunning_official
# bro_code6
# zaiddy50
# yashasvi_shrivastava13
# purani_dilli_waley
# haarishniranj
# mahrishigautam
# jayagarg
# fathiya__em
# sabreenkhannn
# varora17
# kesosykosas.mx
# salmankhan_4007
# romy_dabas
# shaikh_yaser
# pxrthmittal
# __amanattri
# things2doinpatna
# _.anjelly._
# ehsan3136638
# aarifansari35221
# nitigya.1102
# i.am.vishwa_116
# afzaalahmed5581
# prachipandya14
# shwetapandeyy
# yashaberi
# alatinafoods
# si_kj24
# mz2_r
# gtubondje
# thestrayvlogger
# _rishabh17
# _sandeep.r
# _ritik_xoxo
# harshilmahajan2002
# kanak_birthday_decoration_ncr
# _cherryoncake__
# neetu.dhamija2006
# jasleenkaur_0610
# ryshaa5
# sajalmondal9559
# anshika.goyal.244
# tanya9tiwari
# prabhleen8030
# un_9005
# pizzaaaaaa_anuuu
# prettyscents.in
# jeetubisht1999
# ni_tesh2461
# brand_enhance
# catchsimer
# neudoor
# thewaywardvault
# got.a.thought
# bomby_demol
# tarunmhjn24
# bhukkadbynature
# niraj885
# n_i_t_h_i_n_17
# arishanaeem
# micksidoi
# saloni_sj
# aroradentalclinic_malviyanagar
# karishmarwaha
# khushiii.khanna
# puri.saurabh12
# _pooooorva_
# saxena_chitrali
# k_negi_16o3
# aayushi_i_
# paultinaa_1
# 28yaar
# _urbeloved_
# vipul8751
# gothamliveson
# rishabh.1996
# bsbhawnasingh0011
# thewellbehaveddrama
# rinkuuuu_yadav
# irosesingh
# dhawalvinodjain
# aniqashiv
# singhshivaani
# ca_quotes_
# kabira7480
# lazzy_diamond
# whoissoniakundu
# hiramalakar_official
# asif_ozair
# gupta_rakshita
# soni._13
# souravmalhotra21
# yuktaaa_m
# __sukhmann
# mr.jaiswal._
# aannii101010
# raj_ma___
# mittalashu232
# open_road_production
# elirose.style
# ayush.gogia
# indiragoyal24
# trisha_c_arora
# arpitupadhyay01
# vv5610952
# mukulpathak1
# rohit_atolia
# anmindergill
# aaveditam97
# asmat.1710
# arushi_jain_
# koko.kher
# lsprihar
# sahithi_puti
# khurramshehzad85
# dutyfreedays
# jruldecruz
# rachna.ritz15
# food_dailyvlog
# vitasta_creations
# subal_khera88
# kaapi_stained
# jyo.oti_verma
# the_royal_barbeque
# bila.lkhan6080
# golden_1_fire
# i_vishi07
# pujaksingh9
# sakshi_.dhiman
# hakim_lukkka
# samaira__thakur
# mr_riyansh1.7
# anjisinghal32
# dhruvgalgotia1
# rishabh.rohilla
# blackskullnomi
# mr._.mk12
# nripijolly
# chahatchugh.cc
# sarahlalrempuii
# siyagarwal
# being_omnist
# hrsvrdhn__
# shagun.sood.547
# ashmitapetwal
# simp_guy01
# parvez3488
# omniscient_7
# sambarkitchen
# _wtff_.deepika
# wowfood_wowart
# riya_kals
# _.omprakashmishra._
# devansh.ag2001
# i_prikshita
# meenabhatia_
# prakratidawani
# dent__o__care
# erotica__writer
# ashmeet.singh13
# neekeeetos
# seema.gulati06
# sam.khan25
# maahi_47n
# girdharreet
# _nanvi_
# i_know_a_song_or_two
# s.lakhjeet
# 4545454545abcdef
# nancy.singh016
# ramyunn____
# ssweet_n_sassyy
# lisha_reg
# 0987gggggggg
# shailvisingh0108
# shraddha.punjabi
# ramjihamrehai
# narash.yadav.7982
# saisa.shaik
# muhammadzaeembhat
# __food.monkey
# fotografie.in_de
# glamupwithgunjan
# sukeshis
# ruchi.mehtarastogi
# radhikathakral__
# studiomanan
# sakshii.raturi
# lalajee_caterers
# thesniper_sc.30
# anishsharma009
# manashviiiii
# lumiere_77
# bhawnalawera
# iammeghalaggarwal
# shruti.sharma.23
# lakshay.26
# mr.doppler.effect
# beingzeeshanahmad
# jasminedhillon18
# divyasingh_09
# akanksha_gandharv_
# ragini.a01
# kshirja.pvt
# larib__07
# niketa153
# harsh_meena45
# _saurabh___13
# foodie_.world.__
# anu_makeupvibes
# jyotsna.a06
# dr_diksha_hans
# _aarushigupta
# palak__jaggi
# tanyaprajapati07
# monikaswami_ms
# ranumndiya
# kashishgd
# swetaroy_99
# _nandita._x
# kakadesaakssii
# sami._xx
# smrutiseeker
# pooja.more41
# sanyam_khunger
# b_rish18
# chanchal798
# __i.m.zer.0
# bilal__chaudhary__
# pattachitra_sachikant
# rudrakshrajoza
# simmy_03.2k
# 5_top_places
# aur0ra._.vibes
# ishita_s016
# ramez_fars
# pinky_dagar000
# rajatbhallaofficial
# laveena_khattar
# prernaaaaa___
# stepwithca
# rashhhmita
# ividhusood
# __raghavb
# confettionmyplate
# strutandpreen
# ma.rcio2985
# shradhaaroraaggarwal
# _._a_collection_of_cells_._
# priyanka19agarwal
# annaaaa.ig
# pihu_agarwal_07
# sonu_atal_chauhan
# ar__oma_l
# godfather_part_0
# anubhutiiiiiiiiiii
# priyanshii_jainn
# girloholic_
# anusha.singh13
# pbijlani
# ashigupta_12
# dr_mona_swamy
# deeppx._
# maitrisngh
# _n.e.h.a_0301
# anindiangamer
# shifaa.styles
# itz_faizi_1
# sushmita_sush22
# charmshilpenterprise
# madhusingh766796
# gidarabugyaltrek
# siddharth_uno1
# divyak18
# tejs10
# food_is_bae230
# richanegi_
# pushpamsinghrajput
# iamsumitgera
# usman222445
# dark.moon5038
# ishrat0505
# consolationsoflyf
# akshaychhabraofficial07
# ritika_hridaan
# 0786_hayaat
# irenekhalidkeen
# waqaralam2022
# saurav_taneja_
# thakurshubham_1118
# shivam_dhari34
# grungeposting_
# baan_cheli02
# kuku2_8
# suranaharshit
# naazniki
# shashijuhi
# fhlpfh
# divyanshjain12_
# _mokshachallani_
# jyot_98
# its._faizy01
# deepanshugoyal__
# night_mareking
# pravinklekaur
# iamnitin_4u
# mr_vats._143
# muskaan.rathee
# iparasverma__
# vanshajchakoutra
# _manishsahu29
# madhurisfoodmagic
# gaurav_jain_7777
# ni__shh
# kanokam
# sonia_yates
# rishijindal
# _riaa__17
# abhi.jain2406
# bishtii12
# manchitmehta
# chef_sufiyan
# zorifbee
# vinunelce
# pyarrrr
# chaaiaapa
# jait143
# vikrammarkivsingh_art
# surbhij_
# shrutijaiin
# xxyusraxx_
# love_divu_
# raunaqsk
# mandeepsinghleo5
# pravesh4131
# rahul._adr
# arnavparashar
# thelost_musafir_
# rahulkapoor02
# rd11038
# aishwaryaspj
# supriya3133
# dr_kajal_malhotra
# harpreetkaur2446
# jai.tyagi.9235
# supreetgupta
# devil7878787
# arshaq_1
# vickylohia
# majestic_mandeep
# itz_rajinder_
# devxpvts
# anixx_05
# kb9711111227
# tanyadabas_17
# nityakalwani
# alonedp2022
# yadavmdp403638
# sahil_gangwanii
# m_a_r._.28
# wapasmoodswings
# aashish.rathore
# navyabansall
# ella_hvileskov
# ajaydewanirocks
# parvezalam3555
# vatsavvy
# saymafatima
# amithjaain
# raksha9570
# shailja1704
# ahlesunnairan
# chandni_996
# harmannnkaur
# thecrazyfreesoul
# lovebaba1986
# priyanayak_011
# mumbai_stone_service

# %% [markdown]
# # Finding the own Followers

# %%
#6.2 getting the username of my account followers, ie whose username and password is used for running this kernal

driver.get("https://www.instagram.com/")

driver.find_element_by_class_name("gmFkV").click()# cliking on own username that is appering on instagram

follower=wait.until(EC.presence_of_element_located((By.XPATH,"//ul[@class='k9GMp ']//a")))# locating the follower button
follower.click()# clicking on follower button

follower_number=int(follower.text.split()[0])# finding the number of own followers
print("Total number of my followers are: ",follower_number)
scr1=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"isgrP")))# locating the pop-up window in which followers usernames appeared
driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)# scrolling the pop-up-window
own_followers=driver.find_elements_by_class_name("notranslate")# creating the list of selenium object of all usernames
while(len(own_followers)!=follower_number):# process continue till to find all followers
    
    own_followers=driver.find_elements_by_class_name("notranslate")
    driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)
print("My followers are: ")
for j in range(len(own_followers)):
    own_followers[j]=str(own_followers[j].get_attribute("title"))# extracting the username from usename selenium object
    print(own_followers[j])
    
driver.get("https://www.instagram.com/")
# Out:
# Total number of my followers are:  85
# My followers are:
# rajranjan289
# rishabhgoyal_07
# sinumunda102
# bilkamlakra
# __yogesh.s__
# vishwas.yogi
# kalpana_kp05
# shimpirauniyar
# ravigupta2462
# shubham_kumar7482
# charugoyal147
# raj.nandini.22
# _mukeshj_
# trading_signal224
# equitytechnical
# kumarballapavan
# kamalyadav9816
# golu312001
# sehra_lovekush51
# bharti._._
# deepakkumarg770
# 3rij_mohan
# pujapuja1647
# gshilpi565
# kwiqreply
# dipakkumar.gupta.9210
# ravi8364gupta
# __singh_aprajita__
# shrutigupta121
# shivamsingh_om
# daxterous
# _singh199
# muskanjindal2810
# ankit.yadav0141
# jatinkumar12082000
# arjunkumark517
# vikash79033
# thesiddharthshekhar
# deepak_shaundik
# 4_millionairesminds
# rishu_gupta_801104
# anugrah_mittal
# neeraj_billa
# apni_.rasoi
# ravi_gupta271999
# arora.nayan999
# _sourabh_garg_
# garhwal_praveen
# lokesh.arora_
# mohitraj5156
# rohitkashyap_1411
# pathak943
# programmer_world143
# g4bsetup
# vibhorthukral
# abhaykumar001007
# rajeshkashyap593
# j.e.b.y.2
# chint_ugupta
# kaushal_kumar_sunny
# ravigupta9684
# govindasinghkunwar
# dewal_hitt_uu
# purushotam9852
# satyamrathour03
# varunmenon24
# aashishrao432
# alok__yadav9
# ankugupta6887
# raviguptaamba
# tanishq.ameta01
# rachit_keshari_
# lalitkr07
# nikhilkumar3823
# karan632_
# 510dharth_shekhar
# lakshayrana1299
# amman_badsha
# _avi.75
# rajakumar7184
# ck824125
# deven_jain25
# dheeraj_mandal_35k
# riaelytha
# princegupta43518

# %%
#getting the username whom account holder is following 
driver.get("https://www.instagram.com/")

driver.find_element_by_class_name("gmFkV").click()# clicking on username of account holder

following=wait.until(EC.presence_of_all_elements_located((By.XPATH,"//ul[@class='k9GMp ']//a")))# locating the following button
following_number=int(following[1].text.split()[0])# finding the number of following
following[1].click() # clicking on following button
print("Total number of accounts I am following: ",following_number)
scr1=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"isgrP")))# locating the pop-up window on which following username appears
driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)# scrolling the popup winodw to get all username appearing on it
own_following=driver.find_elements_by_class_name("notranslate")# creating the selenium object of all username
while(len(own_following)!=following_number):# process it contiue till we find all followings username
    own_following=driver.find_elements_by_class_name("notranslate")
    driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)
print("Following accounts are: ")
for j in range(len(own_following)):
    own_following[j]=str(own_following[j].get_attribute("title"))# extracting all the username from usename selenium username object
    print(own_following[j])
    
driver.get("https://www.instagram.com/")
# Out:
# Total number of accounts I am following:  352
# Following accounts are:
# garhwal_praveen
# dewal_hitt_uu
# pathak943
# raj.nandini.22
# _sourabh_garg_
# lalitkr07
# golu312001
# kamalyadav9816
# dipakkumar.gupta.9210
# deven_jain25
# mohitraj5156
# sehra_lovekush51
# tanishq.ameta01
# ankit.yadav0141
# __singh_aprajita__
# charugoyal147
# 3rij_mohan
# _avi.75
# ravigupta2462
# rachit_keshari_
# arora.nayan999
# shnehakumari242
# abhaykumar001007
# shrutigupta121
# neeraj_billa
# purushotam9852
# rohitkashyap_1411
# ravi_gupta271999
# deepakkumarg770
# shivamsingh_om
# kumarballapavan
# kalpana_kp05
# 510dharth_shekhar
# nidh.isharma144
# _singh199
# _mukeshj_
# deepak_shaundik
# vibhorthukral
# pujapuja1647
# sinumunda102
# muskanjindal2810
# shubham_kumar7482
# stockguruji2021
# saurav.prakash.gupta
# ankugupta6887
# kaushal_kumar_sunny
# rajeshkashyap593
# karan632_
# mini_rosy455
# __yogesh.s__
# vishwas.yogi
# sunnykumar7933
# shimpirauniyar
# varchasv_thakkar
# varunmenon24
# sona.sonali.100
# rishu_gupta_801104
# sonyrouniyar
# amritgupta8744
# skumar.kr99
# alok__yadav9
# prasad_banarsi
# gshilpi565
# sambhusahu48
# rajranjan289
# solankisubodhkumar
# anugrah_mittal
# rachna.ranade
# daxterous
# stocksgyaan_
# ravi8364gupta
# lakshayrana1299
# aashishrao432
# bharti._._
# ashwini.raj.98892615
# lokendra0204
# pinturauniyar875
# vikash79033
# j.e.b.y.2
# shivam.garg.1106
# apni_.rasoi
# rohitkumarrohit4992
# kantravibabu
# _shurui_
# kwiqreply
# ampupant
# sahilgupta2209
# thepsycho_maniac
# kunner_12
# pink_igupta28
# team_phoenix009
# sujit_kumar_mayank
# kdpdinesh44
# drishti_gk
# im_sachin25
# d.o_djent
# _ravitalks
# ravigupta9684
# bilkamlakra
# ritiksethi21
# santoshkrrfj
# milan.prasad1
# startuplan.es
# jatinbansal_12
# vikashgupta3495
# __aayush007__
# arjunkumark517
# rakesh_kr_suman
# jatinkumar12082000
# setup_tech9
# motivatedlifesoul
# work4kids
# startupbusiness4u
# jaskamboj405
# rajankumargupta19july
# lawkumar83
# rahul4416sharma
# snap.cook
# unfiltered.indian
# s.beura
# ajinkyasinha.08
# theozon.in
# dev.space
# itsmemanojkumar.mk
# rkumarshondik
# dewal.hittu
# be_doozy
# startup_maharashtra
# programmer_funstagram
# lens_nd_engineering
# trading_signal224
# stock_market_updated
# deepabharti468
# py_coder_
# yash__mittal_
# thesiddharthshekhar
# karan_prasad_gupta
# quantelmemes
# akash1870gupta
# discipline_trader15
# rory_james_walker
# princegupta43518
# saurabhtd
# vikashskraj
# aashraya_isha_helpers
# govt_jobs_2021
# programmer_world143
# kaush_sunny
# startuptrev
# lucky_.341
# codermtn
# govindasinghkunwar
# startupstudioonline
# startup_jalsa
# code_student
# entrepreneur_startup_stories
# machine_learning_info
# siddharth.codes
# dataa_nalyst
# rajeshkumarrajeshkumar7409
# govt.jobupdates5
# job_updates_and_hr_knowledge
# dreamacchieverjatin
# english_accept_hs
# nikhilkumar3823
# chint_ugupta
# startup_crackle
# statistics_stats
# indiangovernmentjobs
# earnfromstockmarket
# thehardsecurity
# cafeseason67
# dailycodingquestion
# unwinding_saga
# yogasehogabydrrashti
# govirusgo
# sakambhari_f
# startupsuccessstories.in
# startup_india
# jitendra_choudhary1818
# worldaffairs_fanpage
# ark_fashion_
# data.chatter
# for_nerds_in_programming
# bccl.official
# analystshreedhar
# equitytechnical
# thecareerforce
# startup_talky
# startup_360
# suprememusic__
# proud_programmers
# all_job_updates_here
# jagdishpatil02
# amazing_python3
# _codehub_
# jeetfix
# programmerplus
# rajyasabhatelevision
# code_boom
# varun.5009
# hou_codes
# programer.life
# kings_only_wisdom
# dae.connect
# kickasscoders
# milliondollar.track
# minesminindia
# voadarchitect
# steelminindia
# mensutra_shwetabhgangwar
# geetashlokearth
# unitednationshindi
# tutorialsguru
# delhifeeling
# codeamy
# goistats
# python_scripts
# icodestuff.io
# electronic_brain
# vivek_bharnuke
# fit_with_priya_
# udacity
# uninindia
# dailyinspirationhub
# hereataws
# webentrepreneurship
# the_unity_creators
# geeksport_
# parliament.of.india
# anshikagupta111
# chetchat101
# drdoofficial
# startupselfie_official
# ideadevelopers
# i_am_an_nitian
# startupdaily_
# coding.ninjas
# indiaatun
# ecisveep
# codinganddecoding
# codechef
# datascienceinfo
# success.ingredients
# data_analyst_duo
# programmer.lifestyle
# creativewebdeveloper
# theabsolutevision
# gangstaphilosopher
# humjeetenge
# millionaites
# i_know_python
# winnersthings
# startupstoriesofficial
# nerds_coding
# codingblocks
# geeks_for_geeks
# ieexplained
# pure.python
# thelesbrown
# businessinvestorss
# developers_team
# motivation.formula
# startupnews.fyi
# legendofmotivation
# reliancejio
# peoplewhocode
# thebusiness.mindset
# paytm
# incomeinstitute
# alexmortonmindset
# finshots.in
# 10xidea
# ekkadamsafaltakiorrgk
# nftoverdose
# programmerhumor_io
# smartmindfactory
# billionaire.behaviour
# adv.mandeep_baisla
# fashion_welly
# unacademy
# geekboy
# key2power
# empire_growth
# computersciencelife
# teenprogrammer
# therossharkness
# successpage.uk
# motivationxbeyond
# johncmaxwell
# thecybersecurityhub
# invest_in_mind
# motivationalpark
# motivational.bar
# amit.yt
# john_lee_official
# programmingofficial
# schoolife.in
# namastebihar
# computer_science_engineers
# motivationmonks
# millionaire_process
# stock_market_news_update
# startup.pedia
# javascript.js
# rangdaari_
# beast_thinks
# devilqu0tes
# startup.mp4
# natgeo
# the.legends.says
# moneyforthemind
# billionaire.thinks
# liveyourimpossible
# successparty
# business2success
# financewithsharan
# technicalguruji
# bigdreams.in
# 4_millionaires
# thestockmarketindia
# programmer.me
# python.coder_
# indianstartupnews
# chanakyamotivation
# success__tips
# vivek_bindra
# wealth
# the_hindu
# billionaire_word
# hindihealth
# official_ashishdawar_legalbaba
# kanganaranaut
# successmantra.1
# manojmuntashir
# 6amsuccess
# python.learning
# python.hub
# millionaire_mentor
# indiancricketteam
# motivation_line_
# mindset.therapy
# english.initiative.hub
# sadhguru
# rishabhgoyal_07
# lokesh.arora_
# sumankhatri78
# memesofbihar_
# isro.news.in
# kpmgin
# national__investigation_agency
# iamprabhatchaudhary

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # See the story of certain account

# %%
import time
driver.get("https://www.instagram.com/")
driver.find_element_by_class_name("eyXLr").click()# locating search bar
driver.find_element_by_class_name("XTCLo").send_keys("arjunsuritamaa")# searching coding.ninjas in search bar

coding=wait.until(EC.presence_of_element_located((By.CLASS_NAME,"-qQT3")))
coding.click()# clicking on searched coding.ninjas
time.sleep(3)


    
view=driver.find_element_by_class_name("_2dbep")# locating status button 
view.click()

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------
